# %%
import pandas as pd
import numpy as np

# %%
entity_file = pd.read_excel('C:/Users/25405/Desktop/大数据知识图谱/神话知识图谱/神话人物实体 part1.xlsx')

# %%
entity_file
# Out:
#        人物 神的属性   动物   关系  特定物 地点（居所）  特定事件
# 0     布洛陀  创世神   蛟龙   夫妻    天     水中  嫦娥奔月
# 1     姆六甲   地神    虎   母女    风     岩洞    创世
# 2     母洛甲   圣神   野猪   母子   混沌     天上  月中伐桂
# 3     祖宜婆   女神  癞蛤蟆   父女    洞     山上    填海
# 4     姆洛甲   月神   玉兔   父子    河    敢壮山    担山
# ..    ...  ...  ...  ...  ...    ...   ...
# 318    观音  NaN  NaN  NaN  NaN    NaN   NaN
# 319  南海观音  NaN  NaN  NaN  NaN    NaN   NaN
# 320   莫龙恭  NaN  NaN  NaN  NaN    NaN   NaN
# 321    杞人  NaN  NaN  NaN  NaN    NaN   NaN
# 322     豆  NaN  NaN  NaN  NaN    NaN   NaN
#
# [323 rows x 7 columns]

# %%
df1 = entity_file['人物']
df2 = entity_file['神的属性']
df3 = entity_file['动物']
df4 = entity_file['特定物']
df5 = entity_file['地点（居所）']
lab1 = pd.Series('人物', index = range(len(df1)))
lab2 = pd.Series('神的属性', index = range(len(df2)))
lab3 = pd.Series('动物', index = range(len(df3)))
lab4 = pd.Series('特定物', index = range(len(df4)))
lab5 = pd.Series('地点（居所）', index = range(len(df5)))

# %%
label1 = df1 + ' ' + lab1
label2 = df2 + ' ' + lab2
label3 = df3 + ' ' + lab3
label4 = df4 + ' ' + lab4
label5 = df5 + ' ' + lab5
label1.to_csv('C:/Users/25405/Desktop/大数据知识图谱/神话知识图谱/data_label/label_FUG.txt', sep = '\t', index = False)
label2.to_csv('C:/Users/25405/Desktop/大数据知识图谱/神话知识图谱/data_label/label_ATTRI.txt', sep = '\t', index = False)
label3.to_csv('C:/Users/25405/Desktop/大数据知识图谱/神话知识图谱/data_label/label_ANIMAL.txt', sep = '\t', index = False)
label4.to_csv('C:/Users/25405/Desktop/大数据知识图谱/神话知识图谱/data_label/label_SPEC.txt', sep = '\t', index = False)
label5.to_csv('C:/Users/25405/Desktop/大数据知识图谱/神话知识图谱/data_label/label_LOC.txt', sep = '\t', index = False)
